# %%
# Problem 1: Bank Account Create a class representing a bank account with attributes like account number, 
# account holder name, and balance. Implement methods to deposit and withdraw money from the account.


class BankAccount():
    
    def __init__(self, acct_num, acct_hname, acct_bal):
        self.acct_num = acct_num
        self.acct_hname = acct_hname
        self.acct_bal = acct_bal
        
        
    def deposit_money(self, ammt):
        new_val = self.acct_bal+ammt
        self.acct_bal += ammt
        return (f"your new balance is {new_val}")
    
    def withdraw_money(self, ammt):
        new_val = self.acct_bal-ammt
        self.acct_bal -= ammt
        return (f"please collect your amount {ammt}, your current balance is now {new_val}")

# %%
# Problem 2: Employee Management Create a class representing an employee with attributes like employee ID, name, and salary. 
# Implement methods to calculate the yearly bonus and display employee details.

class Emp():
    
    def __init__(self, emp_id, emp_name, emp_sal):
        self.emp_id = emp_id
        self.emp_name = emp_name
        self.emp_sal = emp_sal
        
        
    
    def emp_details(self):
        return (f"employee name is {self.emp_name} \n employee id is {self.emp_id} \n employee salary is {self.emp_sal}")
    
    def cal_bonus(self,bonus):
        return (f"employee yearly bonus is {bonus}")

# %%
# Problem 3: Vehicle Rental Create a class representing a vehicle rental system. 
# Implement methods to rent a vehicle, return a vehicle, and display available vehicles.
 
    
class vehicle_rental():
    
    def rent_vehicle(self):
        return (f"this method is for renting a vehicle")
    
    def return_vehicle(self):
        return (f"this method is for returning a vehicle")
    
    def display_vehicle(self):
        return (f"this method is for displaying the list of avaialable vehicles")

# %%
# Problem 4: Library Catalog Create classes representing a library and a book.
# Implement methods to add books to the library, borrow books, and display available books.


class Library():
    
    def add_books(self):
        return (f"this method is for adding the books")
    
    
    def borrow_books(self):
        return (f"this method is for borowing the books")
    
    def avaialable_books(self):
        return (f"this method is for showing the available books")

# %%
# Problem 5: Product Inventory Create classes representing a product and an inventory system. 
# Implement methods to add products to the inventory, update product quantity, and display available products.

class store():
    
    def __init__(self, soap, shampoo, facewash, soap_qty, shampoo_qty, facewash_qty):
        self.soap = soap
        self.shampoo = shampoo
        self.facewash = facewash
        self.soap_qty = 1
        self.shampoo_qty = 2
        self.facewash_qty = 3
    
    def update_product(self, product):
        if product == soap:
            self.soap_qty +=1
        
        elif product == shampoo:
            self.shampoo_qty += 1
            
        elif product == facewash:
            self.facewash_qty += 1
            
            
    def add_product(self, product):
        return (f" new product {product} has been added to the inventory")
    
    def display_available(self):
        return (f"available items are {self.soap}, {self.shampoo}, {self.facewash}")

# %%
# Problem 6: Shape Calculation Create a class representing a shape with attributes like length, width, and height. 
# Implement methods to calculate the area and perimeter of the shape.

class Shape():
    
    def __init__(self, length, width, height):
        self.length = length
        self.width = width
        self.height = height
        
        
    def area(self):
        return (f"area of your shape is {2*{self.length*self.width+self.width*self.height+self.height*self.length}}")
    
    def perimtere(self):
        return (f"perimeter of cuboid is {4*(self.length+self.width+self.height)}")

# %%
# Problem 7: Student Management Create a class representing a student with attributes like student ID, name, and grades. 
# Implement methods to calculate the average grade and display student details.


class Acd_Class():
    
    def __init__(self,std_id, std_name, std_grades):
        self.std_id = std_id
        self.std_name = std_name
        self.std_grades = std_grades
        
        
        
    def stud_details(self):
        return (f"student details are {self.std_name} \n {self.std_name}, \n {self.std_grades}")
    
    
    def average_grade(self,m1,m2, m3,m4,m5):
        avg_grade = (m1+m2+m3+m4+m5)/5
        return (f"average grade is {avg_grade}")

# %%
# Problem 8: Email Management Create a class representing an email with attributes like sender, recipient, and subject.
# Implement methods to send an email and display email details.



class Email():
    
    def __init__(self, sender, recipient,subject):
        self.sender = sender
        self.recipient = recipient
        self.subject = subject
        
        
    def send_email(self, message):
        return (f"email has been sent to {self.recipient} from {self.subject} \n with the messsage {message}")
    
    def email_details(self):
        return (f"email details are as follows sender = {self.sender}, recipient = {self.recipient}")

# %%
# Problem 9: Social Media Profile Create a class representing a social media profile with attributes like username and posts.
# Implement methods to add posts, display posts, and search for posts by keyword.

class smedia():
    
    def __init__(self,uname,posts):
        
        self.uname = uname
        self.posts = posts
        
    def add_posts(self,pname):
        return (f"this methid is for adding the posts in socail media profile")
    
    def display_posts(self):
        return (f"this method is for displaying the posts")
    
    def search_post(self):
        return (f"this method is for searching the post by keyword")

# %%
# Problem 10: ToDo List Create a class representing a ToDo list with attributes like tasks and due dates.
# Implement methods to add tasks, mark tasks as completed, and display pending tasks.


class todo():
    
    def __init__(self, tasks, due_date,task_list):
        self.tasks = tasks
        self.due_date = due_date
        self.task_list = []
        
    def add_task(self,task):
        new_task = task
        return self.task_list.append(new_task)
    
    def comp_task(self,task):
        comptask = task
        return self.task_list.remove(comptask)
    
    def show_task(self):
        return self.task_list
